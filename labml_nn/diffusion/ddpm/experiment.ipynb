# %% [markdown]
# <a href="https://colab.research.google.com/github/hhrzwm/simplified-deeplearning/blob/master/labml_nn/diffusion/ddpm/experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Github](https://img.shields.io/github/stars/labmlai/annotated_deep_learning_paper_implementations?style=social)](https://github.com/labmlai/annotated_deep_learning_paper_implementations)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/labmlai/annotated_deep_learning_paper_implementations/blob/master/labml_nn/diffusion/ddpm/experiment.ipynb)
#
# ## [Denoising Diffusion Probabilistic Models (DDPM)](https://nn.labml.ai/diffusion/ddpm/index.html)
#
# This notebook trains a DDPM based model on MNIST digits dataset.

# %% [markdown]
# ### Install the packages

# %%
# !pip install labml-nn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.9/443.9 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 57.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn

from labml import experiment
from labml.configs import option
from labml_nn.diffusion.ddpm.experiment import Configs

# %% [markdown]
# ### Create an experiment

# %%
experiment.create(name="diffuse", writers={'screen'})

# %% [markdown]
# ### Configurations

# %%
configs = Configs()

# %% [markdown]
# Set experiment configurations and assign a configurations dictionary to override configurations

# %%
experiment.configs(configs, {
    'dataset': 'MNIST',
    'image_channels': 1,
    'epochs': 5,
})
# Out:
# <pre style="overflow-x: scroll;"></pre>

# %% [markdown]
# Initializ

# %%
configs.init()
# Out:
# <pre style="overflow-x: scroll;">Prepare device.device...
#   Prepare device.device_info<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	62.78ms</span>
# Prepare device.device<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	66.67ms</span>
# Prepare dataset<span style="color: #00A250">...[DONE]</span><span style="color: #208FFB">	20,774.68ms</span>
# </pre>
# ...
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# ...
# 100%|██████████| 9.91M/9.91M [00:10<00:00, 943kB/s]
# Extracting /content/data/MNISTDataset/raw/train-images-idx3-ubyte.gz to /content/data/MNISTDataset/raw
#
# ...
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# ...
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 151kB/s]
# ...

# %% [markdown]
# Set PyTorch models for loading and saving

# %%
experiment.add_pytorch_models({'eps_model': configs.eps_model})

# %% [markdown]
# ### Start the experiment and run the training loop.

# %%
# Start the experiment
with experiment.start():
    configs.run()
# Out:
# <pre style="overflow-x: scroll;">
# <strong><span style="text-decoration: underline">diffuse</span></strong>: <span style="color: #208FFB">4bf4a79c929d11ef97a90242ac1c000c</span>
# [clean]: <strong><span style="color: #DDB62B">""</span></strong>
# <strong>~/labml/configs.yaml</strong> does not exist. Creating <span style="color: #208FFB">/root/.labml/configs.yaml</span>
# <strong><span style="color: #DDB62B">     938:  </span></strong>Train:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB">   411,728ms  </span>Sample:<span style="color: #C5C1B4"> 100%</span><span style="color: #208FFB"> 56,267ms  </span> loss: <span style="color: #C5C1B4">0.026307</span>  <span style="color: #208FFB">467,995ms</span><span style="color: #D160C4">  0:07m/  0:31m  </span>
# ...
